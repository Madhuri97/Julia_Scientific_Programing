# %%
for num = 3:7
    println("num is now $num")
end
# Out:
# num is now 3
# num is now 4
# num is now 5
# num is now 6
# num is now 7

# %%
testvals = [23, "my name is not a name", 'α'] #iterating arrays
for x in testvals
    println("the value of x is now $x")
end
# Out:
# the value of x is now 23
# the value of x is now my name is not a name
# the value of x is now α

# %%
mylist = [3, 2, 1]
count=1
for i in mylist
  mylist[i]=count
  count=count+1
end

# %%
println("mylist = $mylist")
# Out:
# mylist = [3, 2, 1]

# %%
count=0
for i=1:3
  for j=1:3
    count=count+1
  end
end

# %%
println("count is $count")
# Out:
# count is 9

# %%
summedvals = 3
for k = 1:2:5  
  summedvals = summedvals + k
end
summedvals
# Out:
# 12

# %%
function test(x)
    if x==1 
        return 1
    end
    if x<=0
        return 0
    end
    return test(x-1)+test(x-2)
end
test(3)
# Out:
# 2

# %%
a = rand()
println("a has value $a")
if a > 0.5
    println("the numbers is larger")
end
# Out:
# a has value 0.12400146998892936

# %%
for k = 1:8
    b = rand()
    println("b now has the value $b")
    if b > 0.5
        println("This is quite a large value")
    end
end
# Out:
# b now has the value 0.004023507623853284
# b now has the value 0.16227025387196115
# b now has the value 0.47153166491298637
# b now has the value 0.44871754456603963
# b now has the value 0.6146421737323622
# This is quite a large value
# b now has the value 0.5671268374882259
# This is quite a large value
# b now has the value 0.10511635151673082
# b now has the value 0.3423484824006717

# %%
f(x) = 3 * x^2 + 6 * x - 9
for x = -5:5    
  println("(",x, ", ", f(x), ")")
end
using Plots
gr() # Activate the GR backend for use with Plots
plot(f, -4, 3) # plot f over [-4,4]
plot!(zero, -4, 3)
# Out:
# (-5, 36)
# (-4, 15)
# (-3, 0)
# (-2, -9)
# (-1, -12)
# (0, -9)
# (1, 0)
# (2, 15)
# (3, 36)
# (4, 63)
# (5, 96)

# %%
data = [1.6800483  -1.641695388; 
        0.501309281 -0.977697538; 
        1.528012113 0.52771122;
        1.70012253 1.711524991; 
        1.992493625 1.891000015;
        2.706075824 -0.463427794;
        2.994931927 -0.443566619;
        3.491852811 -1.275179133;
        3.501191722 -0.690499597;
        4.459924502 -5.516130799;
        4.936965851 -6.001703074;
        5.023289852 -8.36416901;
        5.04233698 -7.924477517;
        5.50739285 -10.77482371;
        5.568665171 -10.9171878]
# Out:
# 15×2 Array{Float64,2}:
#  1.68005    -1.6417
#  0.501309   -0.977698
#  1.52801     0.527711
#  1.70012     1.71152
#  1.99249     1.891
#  2.70608    -0.463428
#  2.99493    -0.443567
#  3.49185    -1.27518
#  3.50119    -0.6905
#  4.45992    -5.51613
#  4.93697    -6.0017
#  5.02329    -8.36417
#  5.04234    -7.92448
#  5.50739   -10.7748
#  5.56867   -10.9172

# %%
using Plots
gr()
plot(x, y, linetype = :scatter, leg = false)
# Out:
# UndefVarError: x not defined
#
# Stacktrace:
#  [1] top-level scope at In[4]:2

# %%
x = [1 2 3 4 5 6]'
y = (x.-3).^2/4
plot(x,y, marker = :hex, leg=false, linewidth = 2, linecolor=:black)
plot!(title="Plot for graded quiz")

# %%
x = [1 2 3 4 5 6]'
y = (x.-3).^2/4
plot(x,y, marker = :hex, leg=false, linewidth = 2, linecolor=:black)
plot!(title="Plot for graded quiz")

# %%
x = [1, 2, 3, 4, 5, 6]
y = (x.-3).^2/4
plot(x,y, marker = :hex, leg=false, linewidth = 2, linecolor=:black)
plot!(title="Plot for graded quiz")

# %%
x = [1, 2, 3, 4, 5, 6]
y = (x.-3).^2/4
plot(x,y, marker = :hex, leg=false, linewidth = 2, linecolor=:black)
plot!(title="Plot for graded quiz")
